# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

data1 = pd.read_csv('A-4E_Red_Viper.csv')
data2 = pd.read_csv('F-14A_Blue_Maverick_Goose.csv')

fig = plt.figure().gca(projection = '3d')

fig.scatter(data1['Longitude'] , data1['Latitude'] , data1['Altitude'] , c = 'b')
fig.scatter(data2['Longitude'] , data2['Latitude'] , data2['Altitude'] , c = 'r')

fig.set_xlabel('longitude')
fig.set_ylabel('latitude')
fig.set_zlabel('Altitude')


plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data1 = pd.read_csv('A-4E_Red_Viper.csv')
data2 = pd.read_csv('F-14A_Blue_Maverick_Goose.csv')

fig = plt.figure().gca(projection = '3d')

fig = scatter(data1['Longitude'] , data1['Latitude'] , data1['Altitude'] , c = 'b')
fig = scatter(data2['Longitude'] , data2['Latitude'] , data2['Altitude'] , c = 'r')

fig.set_xlabel('longitude')
fig.set_ylabel('latitude')
fit.set_zlable('Altitude')


fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/spyder/lib/python3.7/site-packages/matplotlib/projections/__init__.py in get_projection_class(projection)
#      57     try:
# ---> 58         return projection_registry.get_projection_class(projection)
#      59     except KeyError:
#
# ~/anaconda3/envs/spyder/lib/python3.7/site-packages/matplotlib/projections/__init__.py in get_projection_class(self, name)
#      24         """
# ---> 25         return self._all_projection_types[name]
#      26
#
# KeyError: '3d'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-17d2ba1144b2> in <module>
#       6 data2 = pd.read_csv('F-14A_Blue_Maverick_Goose.csv')
#       7
# ----> 8 fig = plt.figure().gca(projection = '3d')
#       9
#      10 fig = scatter(data1['Longitude'] , data1['Latitude'] , data1['Altitude'] , c = 'b')
#
# ~/anaconda3/envs/spyder/lib/python3.7/site-packages/matplotlib/figure.py in gca(self, **kwargs)
#    1930
#    1931         # no axes found, so create one which spans the figure
# -> 1932         return self.add_subplot(1, 1, 1, **kwargs)
#    1933
#    1934     def sca(self, a):
#
# ~/anaconda3/envs/spyder/lib/python3.7/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1394         else:
#    1395             projection_class, kwargs, key = \
# -> 1396                 self._process_projection_requirements(*args, **kwargs)
#    1397
#    1398             # try to find the axes with this key in the stack
#
# ~/anaconda3/envs/spyder/lib/python3.7/site-packages/matplotlib/figure.py in _process_projection_requirements(self, polar, projection, *args, **kwargs)
#    1118
#    1119         if isinstance(projection, str) or projection is None:
# -> 1120             projection_class = projections.get_projection_class(projection)
#    1121         elif hasattr(projection, '_as_mpl_axes'):
#    1122             projection_class, extra_kwargs = projection._as_mpl_axes()
#
# ~/anaconda3/envs/spyder/lib/python3.7/site-packages/matplotlib/projections/__init__.py in get_projection_class(projection)
#      58         return projection_registry.get_projection_class(projection)
#      59     except KeyError:
# ---> 60         raise ValueError("Unknown projection %r" % projection)
#      61
#      62
#
# ValueError: Unknown projection '3d'
